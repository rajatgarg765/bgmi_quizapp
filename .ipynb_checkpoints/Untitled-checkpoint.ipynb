# %%
import ssl
import certifi
from urllib.request import urlopen
import json
import pandas as pd
import random
with urlopen("https://opentdb.com/api.php?amount=50&category=21&difficulty=medium&type=multiple") as webpage:
    data=json.loads(webpage.read().decode())
    print(data)
    df=pd.DataFrame(data)
    print(df.head(5))
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
import urllib.request as urlrq
import certifi
import ssl
from urllib.request import urlopen
import json
import pandas as pd
import random
webpage= urlrq.urlopen("https://opentdb.com/api.php?amount=50&category=21&difficulty=medium&type=multiple", cafile=certifi.where())
data=json.loads(webpage.read().decode())
#print(data)
df=pd.DataFrame(data['results'])
print(df.head(5))
# Out:
# <ipython-input-37-22c38e021c75>:8: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   webpage= urlrq.urlopen("https://opentdb.com/api.php?amount=50&category=21&difficulty=medium&type=multiple", cafile=certifi.where())
#   category      type difficulty  \
# 0   Sports  multiple     medium
# 1   Sports  multiple     medium
# 2   Sports  multiple     medium
# 3   Sports  multiple     medium
# 4   Sports  multiple     medium
#
#                                             question       correct_answer  \
# 0  At which bridge does the annual Oxford and Cam...               Putney
# 1  With which team did Michael Schumacher make hi...               Jordan
# 2  Which German sportswear company&#039;s logo is...                 Puma
# 3  What cricketing term denotes a batsman being d...                 Duck
# 4  Which of these teams isn&#039;t a member of th...  Philadelphia Flyers
#
#                                    incorrect_answers
# ...

# %%
df
# Out:
#    category      type difficulty  \
# 0    Sports  multiple     medium
# 1    Sports  multiple     medium
# 2    Sports  multiple     medium
# 3    Sports  multiple     medium
# 4    Sports  multiple     medium
# 5    Sports  multiple     medium
# 6    Sports  multiple     medium
# 7    Sports  multiple     medium
# 8    Sports  multiple     medium
# 9    Sports  multiple     medium
# 10   Sports  multiple     medium
# 11   Sports  multiple     medium
# 12   Sports  multiple     medium
# 13   Sports  multiple     medium
# 14   Sports  multiple     medium
# 15   Sports  multiple     medium
# 16   Sports  multiple     medium
# 17   Sports  multiple     medium
# 18   Sports  multiple     medium
# 19   Sports  multiple     medium
# 20   Sports  multiple     medium
# 21   Sports  multiple     medium
# 22   Sports  multiple     medium
# 23   Sports  multiple     medium
# 24   Sports  multiple     medium
# 25   Sports  multiple     medium
# 26   Sports  multiple     medium
# ...

# %%
df.shape
# Out:
# (50, 6)

# %%
df1=pd.read_csv("pubg_data.csv")

# %%
df1
# Out:
#    category      type difficulty  \
# 0    Sports  multiple     medium
# 1    Sports  multiple     medium
# 2    Sports  multiple     medium
# 3    Sports  multiple     medium
# 4    Sports  multiple     medium
# 5    Sports  multiple     medium
# 6    Sports  multiple     medium
# 7    Sports  multiple     medium
# 8    Sports  multiple     medium
# 9    Sports  multiple     medium
# 10   Sports  multiple     medium
# 11   Sports  multiple     medium
# 12   Sports  multiple     medium
# 13   Sports  multiple     medium
# 14   Sports  multiple     medium
# 15   Sports  multiple     medium
# 16   Sports  multiple     medium
# 17   Sports  multiple     medium
# 18   Sports  multiple     medium
# 19   Sports  multiple     medium
# 20   Sports  multiple     medium
# 21   Sports  multiple     medium
# 22   Sports  multiple     medium
# 23   Sports  multiple     medium
# 24   Sports  multiple     medium
# 25   Sports  multiple     medium
# 26   Sports  multiple     medium
# ...

# %%
l=df1['incorrect_answers']
l
# Out:
# 0                                     GODL , SOUL , TSM
# 1                                      SG, Team XO, TSM
# 2                                       NGX , STE, GODL
# 3                                Saumraj,Jonathon,Scout
# 4                                     Scout,Snax,Mortal
# 5                              Samsung,Iphone13,Oneplus
# 6                                Paraboy,Jonathon,Zuxxy
# 7                 2.5 million $,1 million $,5 million $
# 8                                           2cr,3cr,4cr
# 9                                   OR Esports,Soul,TSM
# 10                                 TSM,GODL,Team Xspark
# 11                                             2x,4x,6x
# 12                                                2,4,5
# 13                                                1,3,4
# 14                                                2,4,5
# 15                              Erangel,Vikendi,Karakin
# 16                                            256,48,16
# ...

# %%
question=df1['question'][1]
correct=df1['correct_answer'][1]
wrong=df1['incorrect_answers'][1]
w=[]
print(wrong)
print(len(wrong))
x=""
wrong   =  [item for item in wrong ]   
for j in range(len(wrong)):
    if wrong[j]!=",":
        x=x+wrong[j]
    if wrong[j]==",":
        w.append(x)
        x=""
w.append(x)
print(correct)
print(w)
# Out:
# SG, Team XO, TSM
# 16
# GODL
# ['SG', ' Team XO', ' TSM']
